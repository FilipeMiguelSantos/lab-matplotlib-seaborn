# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
# %matplotlib inline
import math

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig, ax = plt.subplots(figsize=(5,5))

ax.plot(x, y,linewidth=4,linestyle='dashed')
ax.plot(x, z, linewidth=4, linestyle='dashed')

# %%
#your_fig.savefig("cool_plot_picture.png")

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig2, axes2 = plt.subplots(1,2, figsize=(5,5))
axes2[0].plot(x,y, label = 'Left plot', c='red')
axes2[0].set_title('Left plot')

axes2[1].plot(x,z, label = 'Right plot', c='grey')
axes2[1].set_title('Right plot')
# Out:
# Text(0.5, 1.0, 'Right plot')

# %%
#your_fig.savefig("cool_plot_picture.png")

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig2, axes2 = plt.subplots(1,2, figsize=(10,10))

axes2[0].plot(x,y, label = 'Red plot', c='red')
axes2[0].set_title('Left plot')

axes2[1].plot(x,z, label = 'Grey plot', c='grey')
axes2[1].set_title('Right plot')

for ax in axes2:
    ax.legend()

# %%
#your_fig.savefig("cool_plot_picture.png")

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y1 = x**2
y2 = np.exp(x)

fig,(ax1,ax2) = plt.subplots(1,2, figsize = (9,9))

ax1.plot(x,y1)
ax2.plot(x,y2)

ax2.set_xscale('log')
ax2.set_yscale('log')

# %%
#your_fig.savefig("cool_plot_picture.png")

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here

fig,(ax1,ax2) = plt.subplots(1,2, figsize = (9,9))

ax1.plot(x,y1, label='exponential')
ax2.plot(x,y2, label='logarithmic')

ax2.set_xscale('log')
ax2.set_yscale('log')

ax1.legend()
ax2.legend()

# %%
#your_fig.savefig("cool_plot_picture.png")

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('../data/Fitbit2.csv')
fitbit[200:230]
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 200  2015-11-24            2843  10261      7.62       1              1.182
# 201  2015-11-25            2829   8218      6.11      22              1.142
# 202  2015-11-26            3076    976      7.25      13              1.130
# 203  2015-11-27            3242  10769      8.00      17            725.000
# 204  2015-11-28            3254  11671      8.70       5            643.000
# 205  2015-11-29            3247  14444     10.73      14            618.000
# 206  2015-11-30            4012  23313     17.32      16            550.000
# 207  2015-12-01            3232   1681     12.49      14            750.000
# 208  2015-12-02            3125  10745      8.01      10            634.000
# 209  2015-12-03            3165  10784      8.04      14            774.000
# 210  2015-12-04            2835   1074      8.08      11              1.100
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
fitbit.columns


# MEDIAN STEPS BY WORK_OR_WEEKEND (0=weekends)
# your code here

steps_months = fitbit['Steps'].groupby(fitbit['Months_encoded']).median()
steps_weekday = fitbit['Steps'].groupby(fitbit['Work_or_Weekend']).median()

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))

fig.suptitle('Median steps')

plt.sca(ax1)
steps_months.plot()
plt.xticks(range(12), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'June', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'], rotation=90)

plt.xlabel('Months')
plt.ylabel('Median Steps')

plt.sca(ax2)
steps_weekday.plot(kind='bar', color='orange')
plt.xticks(range(2), ['weekend', 'workday'], rotation=360)
ax2.set_ylim(9000, 11000)

plt.xlabel('weekdays')
plt.ylabel('Median Steps')
# Out:
# Text(0, 0.5, 'Median Steps')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
columns = fitbit[['Minutes Sedentary', 'Minutes Lightly Active', 'Minutes Fairly Active']]

y= fitbit['Steps']

f2, axes = plt.subplots(1,3, figsize = (30,10))

for elem in range(3):
    axes[elem].scatter(columns.iloc[:,elem],y)
    axes[elem].set_title(columns.iloc[:,elem].name)
    axes[elem].set_xlabel('Minutes')
    axes[elem].set_ylabel('Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('../data/titanic.csv')
titanic
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name  Gender        Age  \
# 0                               Braund, Mr. Owen Harris    male  22.000000
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                                Heikkinen, Miss. Laina  female  26.000000
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                              Allen, Mr. William Henry    male  35.000000
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 97.2+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes('number')
# Out:
#       PassengerId  Survived  Pclass        Age  SibSp  Parch      Fare
# 0               1       0.0       3  22.000000      1      0    7.2500
# 1               2       1.0       1  38.000000      1      0   71.2833
# 2               3       1.0       3  26.000000      0      0    7.9250
# 3               4       1.0       1  35.000000      1      0   53.1000
# 4               5       0.0       3  35.000000      0      0    8.0500
# ...           ...       ...     ...        ...    ...    ...       ...
# 1304         1305       NaN       3  29.513190      0      0    8.0500
# 1305         1306       NaN       1  39.000000      0      0  108.9000
# 1306         1307       NaN       3  38.500000      0      0    7.2500
# 1307         1308       NaN       3  29.513190      0      0    8.0500
# 1308         1309       NaN       3  25.315435      1      1   22.3583
#
# [1309 rows x 7 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes('object')
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
figa, ax = plt.subplots(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.style.use('classic')
fig, ax = plt.subplots(figsize = (12,6))

ax.hist('Age', data = titanic)

plt.xlabel('Age')
plt.ylabel('Number of people')

fig.suptitle('Ages Dist')
# Out:
# Text(0.5, 0.98, 'Ages Dist')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
plt.style.use('classic')
fig, (ax1,ax2,ax3) = plt.subplots(1,3,figsize = (12,6))

plt.sca(ax1)
ax1 =titanic['Age'].hist(bins=10)
plt.sca(ax2)
ax2 =titanic['Age'].hist(bins=20)
plt.sca(ax3)
ax3 =titanic['Age'].hist(bins=30)

plt.xlabel('Age')
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here

More groups inside a range of age.

"""
# Out:
# '\nyour comments here\n\nMore groups inside a range of age.\n\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
gender = titanic['Gender'].value_counts()
x= gender.index
fig, ax = plt.subplots(figsize=(6,6))
ax.bar(x,gender, color = ('blue', 'pink'))
plt.xlabel('Gender')
plt.ylabel('Number of people')
# Out:
# Text(0, 0.5, 'Number of people')

# %%
# Method 2 - seaborn
# your code here
sns.barplot(x, gender)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
x="Pclass"
sns.countplot(x, data=titanic)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.boxplot(y=titanic['Age'])

# %%
"""
your comments here

Boxplot shows significant measures concerning the struture of ages in this population. 
For that reason is the best plot for this situation
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here

we can see the median is aprox 28 and most people are between 23 and 37 years old aprox. 
It also show us that we have some outliers of people above 60s.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
sns.catplot(y="Age", kind="violin", data=titanic)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here

Tell us the density of people in a certain age.

"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(titanic["Fare"], titanic["Age"])

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(titanic['Fare'], titanic['Age'])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr(),annot=True)

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
SibSp & Parch for a positive correlation
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x = 'Pclass', y = 'Age', data = titanic)

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.FacetGrid(data = titanic, col = 'Gender').map(plt.hist, "Age")
